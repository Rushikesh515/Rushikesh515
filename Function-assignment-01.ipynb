# %% [markdown]
# ### Write a Python program to get the volume of a sphere with radius 6.

# %%
## Formula --> Volume of sphare = 4/3 pi r^3

# here radius is given = 6

# %%
import math

# %%
math.pi #inbuild PI value
# Out:
# 3.141592653589793

# %%
r = 6 #given in Que

# %%
def volume_of_sphare(x):
    volume_sphare = (4/3 * math.pi * (r * r * r)) #cube is not in math library
    return volume_sphare

# %%
volume_of_sphare(r)
# Out:
# 904.7786842338603

# %% [markdown]
# ![fun_ass_01.PNG](attachment:fun_ass_01.PNG)
